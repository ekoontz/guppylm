# %%
# let's set up our input to generation as we did in generate.ipynb.

# %%
from guppylm.inference import GuppyInference

# %%
import torch

# %%
engine = GuppyInference("checkpoints/best_model.pt", "data/tokenizer.json", "cpu")
# Out:
# GuppyLM loaded: 8.7M params

# %%
input_t = torch.tensor([engine.tokenizer.encode(engine._format_prompt([{"role": "user", "content": "hi"}])).ids],dtype=torch.long,device=engine.device)

# %%
input_t
# Out:
# tensor([[  1,  70,  46, 755,   2,  46,   1,  71,  46]])

# %%
engine.model.config.max_seq_len
# Out:
# 128

# %%
logits, _ = engine.model(input_t[:,-128:])

# %%
logits
# Out:
# tensor([[[-4.7068,  0.9972,  1.7976,  ..., -5.2751, -4.5414, -4.9330],
#          [-5.8652,  0.0132,  0.1127,  ..., -5.9521, -5.4884, -5.9952],
#          [-4.8345,  0.3366, -0.2879,  ..., -4.8428, -4.7378, -4.8194],
#          ...,
#          [-6.8495, -0.0753,  0.8974,  ..., -7.3301, -6.7954, -7.6031],
#          [-6.6342, -0.0867, -0.0215,  ..., -6.5966, -6.1761, -6.6405],
#          [-5.2386,  0.7551, -0.8540,  ..., -5.2208, -5.3976, -5.3481]]],
#        grad_fn=<UnsafeViewBackward0>)

# %%
temperature = 0.7

# %%
temperature
# Out:
# 0.7
